# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.svm import SVC
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Read the training data from a CSV file

# %%
data = pd.read_csv('/content/data_train.csv')
read = pd.DataFrame(data)
data
# Out:
#       label  Age  Language  Sex  Marital  Has_Credit  Field  Month_of_birth  \
# 0         0   34         1    2        6           2     13              12
# 1         0   38         1    1        5           1     10               7
# 2         0   35         1    2        4           2      9               8
# 3         0   27         1    1        5           2     13               7
# 4         0   32         1    2        4           2     10               7
# ...     ...  ...       ...  ...      ...         ...    ...             ...
# 8702      1   38         1    2        4           1     16              12
# 8703      1   32         1    2        4           1      4               1
# 8704      1   24         1    1        7           1      5              10
# 8705      1   31         1    2        4           1      1               6
# 8706      1   40         1    2        4           1      5               4
#
# ...

# %% [markdown]
# Display basic information about the data

# %%
data.shape
# Out:
# (8707, 18)

# %%
data.describe()
# Out:
#              label          Age     Language          Sex      Marital  \
# count  8707.000000  8707.000000  8707.000000  8707.000000  8707.000000
# mean      0.923050    37.690479     1.147468     1.622488     4.540829
# std       0.266527    10.750031     0.354592     0.484792     1.053161
# min       0.000000    19.000000     1.000000     1.000000     1.000000
# 25%       1.000000    29.000000     1.000000     1.000000     4.000000
# 50%       1.000000    36.000000     1.000000     2.000000     4.000000
# 75%       1.000000    44.000000     1.000000     2.000000     5.000000
# max       1.000000    79.000000     2.000000     2.000000     7.000000
#
#         Has_Credit        Field  Month_of_birth  Day_of_birth       Region  \
# count  8707.000000  8707.000000     8707.000000   8707.000000  8707.000000
# mean      1.032043    10.485012        6.360859      1.462157    11.207190
# std       0.176125     5.597442        3.405988      0.498594     3.020191
# ...

# %%
data.isnull().sum()
# Out:
# label                   0
# Age                     0
# Language                0
# Sex                     0
# Marital                 0
# Has_Credit              0
# Field                   0
# Month_of_birth          0
# Day_of_birth            0
# Region                  0
# Number_of_credits       0
# Linked_cards            0
# INPS_mln_sum            0
# INPS_yes_no             0
# Score_level             0
# Score_class             0
# Score_point             0
# Changed_phone_number    0
# dtype: int64

# %% [markdown]
# Replace "-" with 0 in the dataset

# %%
data = data.replace({"-":0})

# %% [markdown]
# Display the modified data

# %%
data
# Out:
#       label  Age  Language  Sex  Marital  Has_Credit  Field  Month_of_birth  \
# 0         0   34         1    2        6           2     13              12
# 1         0   38         1    1        5           1     10               7
# 2         0   35         1    2        4           2      9               8
# 3         0   27         1    1        5           2     13               7
# 4         0   32         1    2        4           2     10               7
# ...     ...  ...       ...  ...      ...         ...    ...             ...
# 8702      1   38         1    2        4           1     16              12
# 8703      1   32         1    2        4           1      4               1
# 8704      1   24         1    1        7           1      5              10
# 8705      1   31         1    2        4           1      1               6
# 8706      1   40         1    2        4           1      5               4
#
# ...

# %% [markdown]
# *   Split the data into features (x) and labels (y)
# *   Split the data into training and testing sets

# %%
x = data.drop('label', axis=1)
y = data['label']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
print(y_train.head())
# Out:
# 6884    1
# 1049    1
# 8469    1
# 8647    1
# 3836    1
# Name: label, dtype: int64

# %%
y_train = y_train

# %% [markdown]
# Standardize the features using StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
y_test = y_test.to_numpy()

# %% [markdown]
# Build a neural network model using Keras

# %%
model = Sequential()
model.add(Dense(64, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Compile the model using binary crossentropy loss and Adam optimizer

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %% [markdown]
# Train the neural network model

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=0)

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
predictions = model.predict(x_test)
accuracy = accuracy_score(y_test, predictions)

# %%
conf_matrix = confusion_matrix(y_test, predictions)

# %%
class_report = classification_report(y_test, predictions)

# %%
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.99

# %%
print("\nConfuion Matrix")
print(conf_matrix)
# Out:
# Confuion Matrix
# [[ 223    1]
#  [  13 2376]]

# %%
print("\nClassification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       224
#            1       1.00      0.99      1.00      2389
#
#     accuracy                           0.99      2613
#    macro avg       0.97      1.00      0.98      2613
# weighted avg       0.99      0.99      0.99      2613

# %%
data1 = pd.read_csv('/content/data_test.csv')
read = pd.DataFrame(data1)

print(data1)
print(read)
# Out:
#     label  Age  Language  Sex  Marital  Has_Credit  Field  Month_of_birth  \
# 0       0   40         1    2        4           1      0               3
# 1       0   36         2    2        4           1      0               5
# 2       0   31         1    2        4           1      0               7
# 3       0   29         1    2        4           1      0               1
# 4       0   38         1    2        4           1      0              10
# 5       0   33         1    2        4           1      0               9
# 6       0   34         1    1        5           1      0               4
# 7       0   28         1    2        4           1      0               8
# 8       0   33         1    1        5           1      0               6
# 9       0   35         1    1        5           1      0              10
# 10      0   25         1    2        6           1      0               4
# 11      0   29         1    2        4           1      0               5
# ...

# %%
datal = datal.replace({"-":0})

# %%
datal
# Out:
#     label  Age  Language  Sex  Marital  Has_Credit  Field  Month_of_birth  \
# 0       0   40         1    2        4           1      0               3
# 1       0   36         2    2        4           1      0               5
# 2       0   31         1    2        4           1      0               7
# 3       0   29         1    2        4           1      0               1
# 4       0   38         1    2        4           1      0              10
# 5       0   33         1    2        4           1      0               9
# 6       0   34         1    1        5           1      0               4
# 7       0   28         1    2        4           1      0               8
# 8       0   33         1    1        5           1      0               6
# 9       0   35         1    1        5           1      0              10
# 10      0   25         1    2        6           1      0               4
# 11      0   29         1    2        4           1      0               5
# ...

# %% [markdown]
# Extract features (nedX) and labels (nedy) from the test data

# %%
nedX = datal.drop('label', axis=1)
nedy = datal['label'].to_numpy()

# %%
nedX.head()
# Out:
#    Age  Language  Sex  Marital  Has_Credit  Field  Month_of_birth  \
# 0   40         1    2        4           1      0               3
# 1   36         2    2        4           1      0               5
# 2   31         1    2        4           1      0               7
# 3   29         1    2        4           1      0               1
# 4   38         1    2        4           1      0              10
#
#    Day_of_birth  Region  Number_of_credits  Linked_cards  INPS_mln_sum  \
# 0             1      12                  2             1           2.4
# 1             1      13                  1             2           0.0
# 2             1      13                  1             1           0.3
# 3             1      13                  1             1           0.9
# 4             1      13                  1             2           4.3
#
#    INPS_yes_no  Score_level  Score_class Score_point  Changed_phone_number
# ...

# %%
print(type(nedy))
# Out:
# <class 'numpy.ndarray'>

# %%
nedy_df = pd.DataFrame(nedy)
nedy_df.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
nedX = scaler.transform(nedX)

# %%
print(type(model))
# Out:
# <class 'sklearn.svm._classes.SVC'>

# %%
logis = model.predict(nedX)

# %% [markdown]
# Evaluate and display the accuracy, confusion matrix, and classification report for the predictions

# %%
print(accuracy_score(nedy, logis))
print(confusion_matrix(nedy, logis))
print(classification_report(nedy, logis))
# Out:
# 1.0
# [[26  0]
#  [ 0 22]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48
